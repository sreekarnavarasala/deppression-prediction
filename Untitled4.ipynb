# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('depression_data.csv')
df.head()
# Out:
#                Name  Age Marital Status    Education Level  \
# 0  Christine Barker   31        Married  Bachelor's Degree
# 1  Jacqueline Lewis   55        Married        High School
# 2    Shannon Church   78        Widowed    Master's Degree
# 3    Charles Jordan   58       Divorced    Master's Degree
# 4      Michael Rich   18         Single        High School
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
# 3                   3     Non-smoker                Moderate
# 4                   0     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# 2          Employed  125332.79                 Low      Unhealthy
# 3        Unemployed    9992.78            Moderate       Moderate
# 4        Unemployed    8595.08                 Low       Moderate
#
#   Sleep Patterns History of Mental Illness History of Substance Abuse  \
# 0           Fair                       Yes                         No
# 1           Fair                       Yes                         No
# 2           Good                        No                         No
# 3           Poor                        No                         No
# 4           Fair                       Yes                         No
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes
# 2                          Yes                         No
# 3                           No                         No
# 4                          Yes                        Yes

# %%
df.shape
# Out:
# (413768, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413768 entries, 0 to 413767
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Name                          413768 non-null  object
#  1   Age                           413768 non-null  int64
#  2   Marital Status                413768 non-null  object
#  3   Education Level               413768 non-null  object
#  4   Number of Children            413768 non-null  int64
#  5   Smoking Status                413768 non-null  object
#  6   Physical Activity Level       413768 non-null  object
#  7   Employment Status             413768 non-null  object
#  8   Income                        413768 non-null  float64
#  9   Alcohol Consumption           413768 non-null  object
#  10  Dietary Habits                413768 non-null  object
#  11  Sleep Patterns                413768 non-null  object
#  12  History of Mental Illness     413768 non-null  object
#  13  History of Substance Abuse    413768 non-null  object
#  14  Family History of Depression  413768 non-null  object
#  15  Chronic Medical Conditions    413768 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 50.5+ MB

# %%
df.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Marital Status                  0
# Education Level                 0
# Number of Children              0
# Smoking Status                  0
# Physical Activity Level         0
# Employment Status               0
# Income                          0
# Alcohol Consumption             0
# Dietary Habits                  0
# Sleep Patterns                  0
# History of Mental Illness       0
# History of Substance Abuse      0
# Family History of Depression    0
# Chronic Medical Conditions      0
# dtype: int64

# %%
df['Marital Status'].unique()
# Out:
# array(['Married', 'Widowed', 'Divorced', 'Single'], dtype=object)

# %%
# encode the marital status type

mapped = {'Single':0,'Married':1,'Divorced':2,'Widowed':3}
df['Marital Status'] = df['Marital Status'].map(mapped)

# %%
df.head(3)
# Out:
#                Name  Age  Marital Status    Education Level  \
# 0  Christine Barker   31               1  Bachelor's Degree
# 1  Jacqueline Lewis   55               1        High School
# 2    Shannon Church   78               3    Master's Degree
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# 2          Employed  125332.79                 Low      Unhealthy
#
#   Sleep Patterns History of Mental Illness History of Substance Abuse  \
# 0           Fair                       Yes                         No
# 1           Fair                       Yes                         No
# 2           Good                        No                         No
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes
# 2                          Yes                         No

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's Degree", 'High School', "Master's Degree",
#        'Associate Degree', 'PhD'], dtype=object)

# %%
# encode the education level
mapped = {'High School':0,"Bachelor's Degree":1,"Master's Degree":2, 'Associate Degree':3,'PhD':4}
df['Education Level'] = df['Education Level'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#   Smoking Status Physical Activity Level Employment Status    Income  \
# 0     Non-smoker                  Active        Unemployed  26265.67
# 1     Non-smoker               Sedentary          Employed  42710.36
#
#   Alcohol Consumption Dietary Habits Sleep Patterns History of Mental Illness  \
# 0            Moderate       Moderate           Fair                       Yes
# 1                High      Unhealthy           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
#
#   Chronic Medical Conditions
# 0                        Yes
# 1                        Yes

# %%
df['Smoking Status'].unique()
# Out:
# array(['Non-smoker', 'Former', 'Current'], dtype=object)

# %%
# encode the Smoking status
mapped = {'Non-smoker':0,'Former':1,'Current':2}
df['Smoking Status'] = df['Smoking Status'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status Physical Activity Level Employment Status    Income  \
# 0               0                  Active        Unemployed  26265.67
# 1               0               Sedentary          Employed  42710.36
#
#   Alcohol Consumption Dietary Habits Sleep Patterns History of Mental Illness  \
# 0            Moderate       Moderate           Fair                       Yes
# 1                High      Unhealthy           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
#
#   Chronic Medical Conditions
# 0                        Yes
# 1                        Yes

# %%
df['Physical Activity Level'].unique()
# Out:
# array(['Active', 'Sedentary', 'Moderate'], dtype=object)

# %%
# encode the physical activity level
mapped = {'Sedentary':0,'Active':1,'Moderate':2}
df['Physical Activity Level'] = df['Physical Activity Level'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level Employment Status    Income  \
# 0               0                        1        Unemployed  26265.67
# 1               0                        0          Employed  42710.36
#
#   Alcohol Consumption Dietary Habits Sleep Patterns History of Mental Illness  \
# 0            Moderate       Moderate           Fair                       Yes
# 1                High      Unhealthy           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
#
#   Chronic Medical Conditions
# 0                        Yes
# 1                        Yes

# %%
df['Employment Status'].unique()
# Out:
# array(['Unemployed', 'Employed'], dtype=object)

# %%
# encode the Employment Status
mapped = {'Unemployed':0,'Employed':1}
df['Employment Status'] = df['Employment Status'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#   Alcohol Consumption Dietary Habits Sleep Patterns History of Mental Illness  \
# 0            Moderate       Moderate           Fair                       Yes
# 1                High      Unhealthy           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
#
#   Chronic Medical Conditions
# 0                        Yes
# 1                        Yes

# %%
df['Alcohol Consumption'].unique()
# Out:
# array(['Moderate', 'High', 'Low'], dtype=object)

# %%
# encode the Alcohol Consumption
mapped = {'Low':0,'Moderate':1,'High':2}
df['Alcohol Consumption'] = df['Alcohol Consumption'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#    Alcohol Consumption Dietary Habits Sleep Patterns  \
# 0                    1       Moderate           Fair
# 1                    2      Unhealthy           Fair
#
#   History of Mental Illness History of Substance Abuse  \
# 0                       Yes                         No
# 1                       Yes                         No
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes

# %%
df['Dietary Habits'].unique()
# Out:
# array(['Moderate', 'Unhealthy', 'Healthy'], dtype=object)

# %%
# encode the Dietary habits
mapped = {'Unhealthy':0,'Moderate':1,'Healthy':2}
df['Dietary Habits'] = df['Dietary Habits'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#    Alcohol Consumption  Dietary Habits Sleep Patterns  \
# 0                    1               1           Fair
# 1                    2               0           Fair
#
#   History of Mental Illness History of Substance Abuse  \
# 0                       Yes                         No
# 1                       Yes                         No
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes

# %%
df['Sleep Patterns'].unique()
# Out:
# array(['Fair', 'Good', 'Poor'], dtype=object)

# %%
# encode the sleep patterns
mapped = {'Poor':0,'Fair':1,'Good':2}
df['Sleep Patterns'] = df['Sleep Patterns'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#    Alcohol Consumption  Dietary Habits  Sleep Patterns  \
# 0                    1               1               1
# 1                    2               0               1
#
#   History of Mental Illness History of Substance Abuse  \
# 0                       Yes                         No
# 1                       Yes                         No
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes

# %%
df['History of Mental Illness'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# encode the History of Mental Illness
mapped = {'No':0,'Yes':1}
df['History of Mental Illness'] = df['History of Mental Illness'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#    Alcohol Consumption  Dietary Habits  Sleep Patterns  \
# 0                    1               1               1
# 1                    2               0               1
#
#    History of Mental Illness History of Substance Abuse  \
# 0                          1                         No
# 1                          1                         No
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes

# %%
df['History of Substance Abuse'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# encode the History of Substance Abuse
mapped = {'No':0,'Yes':1}
df['History of Substance Abuse'] = df['History of Substance Abuse'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#    Alcohol Consumption  Dietary Habits  Sleep Patterns  \
# 0                    1               1               1
# 1                    2               0               1
#
#    History of Mental Illness  History of Substance Abuse  \
# 0                          1                           0
# 1                          1                           0
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes

# %%
df['Family History of Depression'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# encode the family history of depression
mapped = {'No':0,'Yes':1}
df['Family History of Depression'] = df['Family History of Depression'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#    Alcohol Consumption  Dietary Habits  Sleep Patterns  \
# 0                    1               1               1
# 1                    2               0               1
#
#    History of Mental Illness  History of Substance Abuse  \
# 0                          1                           0
# 1                          1                           0
#
#    Family History of Depression Chronic Medical Conditions
# 0                             1                        Yes
# 1                             0                        Yes

# %%
df['Chronic Medical Conditions'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# encode the chronic medical conditions
mapped = {'No':0,'Yes':1}
df['Chronic Medical Conditions'] = df['Chronic Medical Conditions'].map(mapped)

# %%
df.head(2)
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               1                1                   2
# 1  Jacqueline Lewis   55               1                0                   1
#
#    Smoking Status  Physical Activity Level  Employment Status    Income  \
# 0               0                        1                  0  26265.67
# 1               0                        0                  1  42710.36
#
#    Alcohol Consumption  Dietary Habits  Sleep Patterns  \
# 0                    1               1               1
# 1                    2               0               1
#
#    History of Mental Illness  History of Substance Abuse  \
# 0                          1                           0
# 1                          1                           0
#
#    Family History of Depression  Chronic Medical Conditions
# 0                             1                           1
# 1                             0                           1

# %%
df.drop('Name',inplace=True,axis=1)

# %%
df.head(2)
# Out:
#    Age  Marital Status  Education Level  Number of Children  Smoking Status  \
# 0   31               1                1                   2               0
# 1   55               1                0                   1               0
#
#    Physical Activity Level  Employment Status    Income  Alcohol Consumption  \
# 0                        1                  0  26265.67                    1
# 1                        0                  1  42710.36                    2
#
#    Dietary Habits  Sleep Patterns  History of Mental Illness  \
# 0               1               1                          1
# 1               0               1                          1
#
#    History of Substance Abuse  Family History of Depression  \
# 0                           0                             1
# 1                           0                             0
#
#    Chronic Medical Conditions
# 0                           1
# 1                           1

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
x = df.drop('Chronic Medical Conditions',axis=1)
y = df['Chronic Medical Conditions']

xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=100)

# %%
lg = LogisticRegression()
lg.fit(xtrain,ytrain)
ypred = lg.predict(xtest)

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80     55559
#            1       0.00      0.00      0.00     27195
#
#     accuracy                           0.67     82754
#    macro avg       0.34      0.50      0.40     82754
# weighted avg       0.45      0.67      0.54     82754

# %% [markdown]
# # feature engineering

# %%
df
# Out:
#         Age  Marital Status  Education Level  Number of Children  \
# 0        31               1                1                   2
# 1        55               1                0                   1
# 2        78               3                2                   1
# 3        58               2                2                   3
# 4        18               0                0                   0
# ...     ...             ...              ...                 ...
# 413763   68               1                2                   0
# 413764   26               0                1                   0
# 413765   57               1                1                   0
# 413766   71               1                3                   2
# 413767   62               3                2                   0
#
#         Smoking Status  Physical Activity Level  Employment Status     Income  \
# 0                    0                        1                  0   26265.67
# 1                    0                        0                  1   42710.36
# 2                    0                        0                  1  125332.79
# 3                    0                        2                  0    9992.78
# 4                    0                        0                  0    8595.08
# ...                ...                      ...                ...        ...
# 413763               1                        2                  1  109233.43
# 413764               2                        1                  1   96760.97
# 413765               0                        0                  1   77353.26
# 413766               0                        0                  0   24557.08
# 413767               1                        2                  1  107125.74
#
#         Alcohol Consumption  Dietary Habits  Sleep Patterns  \
# 0                         1               1               1
# 1                         2               0               1
# 2                         0               0               2
# 3                         1               1               0
# 4                         0               1               1
# ...                     ...             ...             ...
# 413763                    0               2               2
# 413764                    0               2               0
# 413765                    1               1               1
# 413766                    1               1               0
# 413767                    1               2               2
#
#         History of Mental Illness  History of Substance Abuse  \
# 0                               1                           0
# 1                               1                           0
# 2                               0                           0
# 3                               0                           0
# 4                               1                           0
# ...                           ...                         ...
# 413763                          0                           0
# 413764                          1                           1
# 413765                          0                           0
# 413766                          0                           1
# 413767                          0                           1
#
#         Family History of Depression  Chronic Medical Conditions
# 0                                  1                           1
# 1                                  0                           1
# 2                                  1                           0
# 3                                  0                           0
# 4                                  1                           1
# ...                              ...                         ...
# 413763                             0                           0
# 413764                             0                           1
# 413765                             1                           1
# 413766                             0                           0
# 413767                             0                           0
#
# [413768 rows x 15 columns]

# %%
df['smoking_alchol'] = df['Smoking Status'].astype(str) +"_"+ df['Alcohol Consumption'].astype(str)

from sklearn.preprocessing import PolynomialFeatures
numeric_features = ['Age','Income']
poly = PolynomialFeatures(degree=2 , interaction_only=False , include_bias=False)
poly_features = poly.fit_transform(df[numeric_features])
poly_df = pd.DataFrame(poly_features,columns=poly.get_feature_names_out(numeric_features))

df = pd.concat([df,poly_df],axis=1)

# %%
df
# Out:
#        Age  Marital Status  Education Level  Number of Children  \
# 0       31               1                1                   2
# 1       55               1                0                   1
# 2       78               3                2                   1
# 3       58               2                2                   3
# 4       18               0                0                   0
# ...     ..             ...              ...                 ...
# 413763  68               1                2                   0
# 413764  26               0                1                   0
# 413765  57               1                1                   0
# 413766  71               1                3                   2
# 413767  62               3                2                   0
#
#         Smoking Status  Physical Activity Level  Employment Status     Income  \
# 0                    0                        1                  0   26265.67
# 1                    0                        0                  1   42710.36
# 2                    0                        0                  1  125332.79
# 3                    0                        2                  0    9992.78
# 4                    0                        0                  0    8595.08
# ...                ...                      ...                ...        ...
# 413763               1                        2                  1  109233.43
# 413764               2                        1                  1   96760.97
# 413765               0                        0                  1   77353.26
# 413766               0                        0                  0   24557.08
# 413767               1                        2                  1  107125.74
#
#         Alcohol Consumption  Dietary Habits  ...  History of Mental Illness  \
# 0                         1               1  ...                          1
# 1                         2               0  ...                          1
# 2                         0               0  ...                          0
# 3                         1               1  ...                          0
# 4                         0               1  ...                          1
# ...                     ...             ...  ...                        ...
# 413763                    0               2  ...                          0
# 413764                    0               2  ...                          1
# 413765                    1               1  ...                          0
# 413766                    1               1  ...                          0
# 413767                    1               2  ...                          0
#
#         History of Substance Abuse  Family History of Depression  \
# 0                                0                             1
# 1                                0                             0
# 2                                0                             1
# 3                                0                             0
# 4                                0                             1
# ...                            ...                           ...
# 413763                           0                             0
# 413764                           1                             0
# 413765                           0                             1
# 413766                           1                             0
# 413767                           1                             0
#
#         Chronic Medical Conditions  smoking_alchol   Age     Income   Age^2  \
# 0                                1             0_1  31.0   26265.67   961.0
# 1                                1             0_2  55.0   42710.36  3025.0
# 2                                0             0_0  78.0  125332.79  6084.0
# 3                                0             0_1  58.0    9992.78  3364.0
# 4                                1             0_0  18.0    8595.08   324.0
# ...                            ...             ...   ...        ...     ...
# 413763                           0             1_0  68.0  109233.43  4624.0
# 413764                           1             2_0  26.0   96760.97   676.0
# 413765                           1             0_1  57.0   77353.26  3249.0
# 413766                           0             0_1  71.0   24557.08  5041.0
# 413767                           0             1_1  62.0  107125.74  3844.0
#
#         Age Income      Income^2
# 0        814235.77  6.898854e+08
# 1       2349069.80  1.824175e+09
# 2       9775957.62  1.570831e+10
# 3        579581.24  9.985565e+07
# 4        154711.44  7.387540e+07
# ...            ...           ...
# 413763  7427873.24  1.193194e+10
# 413764  2515785.22  9.362685e+09
# 413765  4409135.82  5.983527e+09
# 413766  1743552.68  6.030502e+08
# 413767  6641795.88  1.147592e+10
#
# [413768 rows x 21 columns]

# %% [markdown]
# # handling class imbalance

# %%
from imblearn.over_sampling import SMOTE
x = df.drop('Chronic Medical Conditions',axis=1)
y = df['Chronic Medical Conditions']
smote = SMOTE()
x_resampled,y_resampled = smote.fit_resample(x,y)

x_train , x_test , y_train , y_test = train_test_split(x_resampled,y_resampled,train_size=0.8,random_state=100)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
x_train
# Out:
#         Age  Marital Status  Education Level  Number of Children  \
# 481685   52               1                3                   1
# 534542   37               1                0                   1
# 329626   34               1                2                   0
# 320189   31               1                3                   4
# 258638   30               0                3                   0
# ...     ...             ...              ...                 ...
# 344414   54               1                3                   0
# 212912   63               1                1                   1
# 65615    24               0                1                   0
# 210755   42               1                3                   1
# 56088    28               0                1                   0
#
#         Smoking Status  Physical Activity Level  Employment Status  \
# 481685               1                        2                  1
# 534542               0                        1                  1
# 329626               1                        0                  1
# 320189               1                        0                  1
# 258638               0                        1                  1
# ...                ...                      ...                ...
# 344414               0                        0                  0
# 212912               1                        0                  1
# 65615                0                        1                  1
# 210755               1                        0                  1
# 56088                2                        1                  1
#
#                Income  Alcohol Consumption  Dietary Habits  Sleep Patterns  \
# 481685  114921.407091                    0               1               0
# 534542   44499.645375                    1               1               1
# 329626   80068.420000                    2               1               2
# 320189   33345.090000                    1               0               1
# 258638   58088.430000                    0               0               2
# ...               ...                  ...             ...             ...
# 344414   14602.360000                    1               1               2
# 212912   93833.340000                    2               0               0
# 65615    70330.740000                    0               2               2
# 210755   38174.670000                    0               0               0
# 56088   106349.470000                    2               1               0
#
#         History of Mental Illness  History of Substance Abuse  \
# 481685                          0                           0
# 534542                          0                           0
# 329626                          0                           0
# 320189                          0                           0
# 258638                          0                           0
# ...                           ...                         ...
# 344414                          1                           0
# 212912                          0                           0
# 65615                           0                           0
# 210755                          0                           0
# 56088                           0                           1
#
#         Family History of Depression smoking_alchol        Age         Income  \
# 481685                             0       10.36312  52.541843  114921.407091
# 534542                             0       4.139789  37.686021   44499.645375
# 329626                             0           12.0  34.000000   80068.420000
# 320189                             1           11.0  31.000000   33345.090000
# 258638                             0            0.0  30.000000   58088.430000
# ...                              ...            ...        ...            ...
# 344414                             0            1.0  54.000000   14602.360000
# 212912                             0           12.0  63.000000   93833.340000
# 65615                              0            0.0  24.000000   70330.740000
# 210755                             0           10.0  42.000000   38174.670000
# 56088                              0           22.0  28.000000  106349.470000
#
#               Age^2    Age Income      Income^2
# 481685  2771.977222  6.038195e+06  1.320693e+10
# 534542  1420.451580  1.677015e+06  1.980218e+09
# 329626  1156.000000  2.722326e+06  6.410952e+09
# 320189   961.000000  1.033698e+06  1.111895e+09
# 258638   900.000000  1.742653e+06  3.374266e+09
# ...             ...           ...           ...
# 344414  2916.000000  7.885274e+05  2.132289e+08
# 212912  3969.000000  5.911500e+06  8.804696e+09
# 65615    576.000000  1.687938e+06  4.946413e+09
# 210755  1764.000000  1.603336e+06  1.457305e+09
# 56088    784.000000  2.977785e+06  1.131021e+10
#
# [444097 rows x 20 columns]

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
ypred = rf.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.86      0.75     55459
#            1       0.80      0.57      0.66     55566
#
#     accuracy                           0.71    111025
#    macro avg       0.73      0.71      0.71    111025
# weighted avg       0.73      0.71      0.71    111025
